# %% [markdown]
# <a href="https://colab.research.google.com/github/waltechel/KaggleStudy20220103/blob/master/chapter07/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from keras.layers import Input, Activation, Conv2D, Flatten, Dense, MaxPooling2D, Dropout, Add, LeakyReLU, UpSampling2D
from keras.models import Model, load_model
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# # Load Dataset
# - 빵형의 유튜브에 나와 있는 자료를 사용하면 된다
# - dataset 폴더를 만들고 npy 파일을 import해서 사용한다

# %%
x_train = np.load('dataset/x_train.npy')
y_train = np.load('dataset/y_train.npy')
x_val = np.load('dataset/x_val.npy')
y_val = np.load('dataset/y_val.npy')

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (240, 256, 256, 1) (240, 256, 256, 1)
# (27, 256, 256, 1) (27, 256, 256, 1)

# %% [markdown]
# # Build Model

# %%
inputs = Input(shape=(256, 256, 1))

net = Conv2D(32, kernel_size=3, activation='relu', padding='same')(inputs)
net = MaxPooling2D(pool_size=2, padding='same')(net)

net = Conv2D(64, kernel_size=3, activation='relu', padding='same')(net)
net = MaxPooling2D(pool_size=2, padding='same')(net)

net = Conv2D(128, kernel_size=3, activation='relu', padding='same')(net)
net = MaxPooling2D(pool_size=2, padding='same')(net)

net = Dense(128, activation='relu')(net)

net = UpSampling2D(size=2)(net)
net = Conv2D(128, kernel_size=3, activation='sigmoid', padding='same')(net)

net = UpSampling2D(size=2)(net)
net = Conv2D(64, kernel_size=3, activation='sigmoid', padding='same')(net)

net = UpSampling2D(size=2)(net)
outputs = Conv2D(1, kernel_size=3, activation='sigmoid', padding='same')(net)

model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc', 'mse'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 1)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  dense (Dense)               (None, 32, 32, 128)       16512
#
#  up_sampling2d (UpSampling2D  (None, 64, 64, 128)      0
#  )
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 128)       147584
#
#  up_sampling2d_1 (UpSampling  (None, 128, 128, 128)    0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 64)      73792
#
#  up_sampling2d_2 (UpSampling  (None, 256, 256, 64)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 1)       577
#
# =================================================================
# Total params: 331,137
# Trainable params: 331,137
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train
# - 코랩 gpu로 바꾸고 하면 금방 된다
# - 빵형은 1회독에 1분 정도 걸리는 거 같던데 실제로는 그거보다 훨씬 적게 걸릴 수 있다

# %%
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=100, batch_size=32, callbacks=[
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, verbose=1, mode='auto', min_lr=1e-05)
])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 22s 943ms/step - loss: 0.5789 - acc: 0.7006 - mse: 0.1918 - val_loss: 0.5207 - val_acc: 0.7467 - val_mse: 0.1706 - lr: 0.0010
# Epoch 2/100
# 8/8 [==============================] - 3s 374ms/step - loss: 0.4871 - acc: 0.7627 - mse: 0.1590 - val_loss: 0.4606 - val_acc: 0.7467 - val_mse: 0.1540 - lr: 0.0010
# Epoch 77/100
# 8/8 [==============================] - 3s 381ms/step - loss: 0.0333 - acc: 0.9863 - mse: 0.0066 - val_loss: 0.1186 - val_acc: 0.9717 - val_mse: 0.0204 - lr: 2.0000e-04
# Epoch 78/100
# 8/8 [==============================] - 3s 383ms/step - loss: 0.0328 - acc: 0.9865 - mse: 0.0065 - val_loss: 0.1187 - val_acc: 0.9717 - val_mse: 0.0204 - lr: 2.0000e-04
# Epoch 79/100
# 8/8 [==============================] - 3s 381ms/step - loss: 0.0326 - acc: 0.9865 - mse: 0.0064 - val_loss: 0.1187 - val_acc: 0.9716 - val_mse: 0.0204 - lr: 2.0000e-04
# Epoch 80/100
# 8/8 [==============================] - 3s 380ms/step - loss: 0.0325 - acc: 0.9866 - mse: 0.0064 - val_loss: 0.1183 - val_acc: 0.9717 - val_mse: 0.0204 - lr: 2.0000e-04
# Epoch 81/100
# 8/8 [==============================] - 3s 384ms/step - loss: 0.0323 - acc: 0.9867 - mse: 0.0064 - val_loss: 0.1184 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 2.0000e-04
# Epoch 82/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0323 - acc: 0.9867 - mse: 0.0064 - val_loss: 0.1192 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 2.0000e-04
# Epoch 83/100
# 8/8 [==============================] - 3s 381ms/step - loss: 0.0322 - acc: 0.9867 - mse: 0.0063 - val_loss: 0.1181 - val_acc: 0.9717 - val_mse: 0.0204 - lr: 2.0000e-04
# Epoch 84/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0320 - acc: 0.9868 - mse: 0.0063
# Epoch 84: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 8/8 [==============================] - 3s 380ms/step - loss: 0.0320 - acc: 0.9868 - mse: 0.0063 - val_loss: 0.1198 - val_acc: 0.9717 - val_mse: 0.0203 - lr: 2.0000e-04
# Epoch 85/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0320 - acc: 0.9868 - mse: 0.0063 - val_loss: 0.1193 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 86/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0318 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1191 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 87/100
# 8/8 [==============================] - 3s 383ms/step - loss: 0.0318 - acc: 0.9868 - mse: 0.0062 - val_loss: 0.1191 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 88/100
# 8/8 [==============================] - 3s 381ms/step - loss: 0.0318 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1191 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 89/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0318 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1191 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 90/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0317 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1194 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 91/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.0317 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1192 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 92/100
# 8/8 [==============================] - 3s 383ms/step - loss: 0.0317 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1191 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 93/100
# 8/8 [==============================] - 3s 382ms/step - loss: 0.0317 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1194 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 94/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0317 - acc: 0.9869 - mse: 0.0062
# Epoch 94: ReduceLROnPlateau reducing learning rate to 1e-05.
# 8/8 [==============================] - 3s 383ms/step - loss: 0.0317 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1190 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 4.0000e-05
# Epoch 95/100
# 8/8 [==============================] - 3s 384ms/step - loss: 0.0316 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1192 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 1.0000e-05
# Epoch 96/100
# 8/8 [==============================] - 3s 380ms/step - loss: 0.0316 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1193 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 1.0000e-05
# Epoch 97/100
# 8/8 [==============================] - 3s 379ms/step - loss: 0.0316 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1194 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 1.0000e-05
# Epoch 98/100
# 8/8 [==============================] - 3s 380ms/step - loss: 0.0316 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1193 - val_acc: 0.9719 - val_mse: 0.0203 - lr: 1.0000e-05
# Epoch 99/100
# 8/8 [==============================] - 3s 380ms/step - loss: 0.0316 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1194 - val_acc: 0.9719 - val_mse: 0.0203 - lr: 1.0000e-05
# Epoch 100/100
# 8/8 [==============================] - 3s 380ms/step - loss: 0.0316 - acc: 0.9869 - mse: 0.0062 - val_loss: 0.1193 - val_acc: 0.9718 - val_mse: 0.0203 - lr: 1.0000e-05

# %% [markdown]
# # Evaluation

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 7))

ax[0, 0].set_title('loss')
ax[0, 0].plot(history.history['loss'], 'r')
ax[0, 1].set_title('acc')
ax[0, 1].plot(history.history['acc'], 'b')

ax[1, 0].set_title('val_loss')
ax[1, 0].plot(history.history['val_loss'], 'r--')
ax[1, 1].set_title('val_acc')
ax[1, 1].plot(history.history['val_acc'], 'b--')

# %%
preds = model.predict(x_val)

fig, ax = plt.subplots(len(x_val), 3, figsize=(10, 100))

for i, pred in enumerate(preds):
    ax[i, 0].imshow(x_val[i].squeeze(), cmap='gray')
    ax[i, 1].imshow(y_val[i].squeeze(), cmap='gray')
    ax[i, 2].imshow(pred.squeeze(), cmap='gray')
